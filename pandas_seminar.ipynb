# %%
persons_info = [{'id':1,'name':'Anil','sal':300000},
                {'id':5,'name':'Rajesh','sal':400000},
                {'id':4,'name':'Pavan','sal':500000},
                {'id':6,'name':'Ashok','sal':600000},
                {'id':3,'name':'Naveen','sal':200000},
                {'id':2,'name':'Jadeesh','sal':500000},
               ]
# find out who is getting max, min salaries
# findoout average salary

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame(persons_info)

# %%
df
# Out:
#    id     name     sal
# 0   1     Anil  300000
# 1   5   Rajesh  400000
# 2   4    Pavan  500000
# 3   6    Ashok  600000
# 4   3   Naveen  200000
# 5   2  Jadeesh  500000

# %%
# get columns
df.columns
# Out:
# Index([u'id', u'name', u'sal'], dtype='object')

# %%
# get name column data
df.name
# Out:
# 0       Anil
# 1     Rajesh
# 2      Pavan
# 3      Ashok
# 4     Naveen
# 5    Jadeesh
# Name: name, dtype: object

# %%
# get id column data
df.id
# Out:
# 0    1
# 1    5
# 2    4
# 3    6
# 4    3
# 5    2
# Name: id, dtype: int64

# %%
# if you want to get name and id
df[['id','name']]
# Out:
#    id     name
# 0   1     Anil
# 1   5   Rajesh
# 2   4    Pavan
# 3   6    Ashok
# 4   3   Naveen
# 5   2  Jadeesh

# %%
# get row wise data using .loc, .iloc, .ix
# in pandas row can be recognised using position or an index
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# is it possible to chnage the default index?.. Give a dates as an index to the above data
dates = pd.date_range('20160101',periods=6)
dates
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# what is the freq argument?
dates = pd.date_range('20160101',periods=6,freq='M')
dates
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
dates = pd.date_range('20160101',periods=6,freq='H')
dates
# Out:
# DatetimeIndex(['2016-01-01 00:00:00', '2016-01-01 01:00:00',
#                '2016-01-01 02:00:00', '2016-01-01 03:00:00',
#                '2016-01-01 04:00:00', '2016-01-01 05:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
dates = pd.date_range('20160101',periods=6,freq='M')
dates
# Out:
# DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31', '2016-04-30',
#                '2016-05-31', '2016-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
df.index = dates
df
# Out:
#             id     name     sal
# 2016-01-31   1     Anil  300000
# 2016-02-29   5   Rajesh  400000
# 2016-03-31   4    Pavan  500000
# 2016-04-30   6    Ashok  600000
# 2016-05-31   3   Naveen  200000
# 2016-06-30   2  Jadeesh  500000

# %%
# default iteration gives only columns
for i in df:
    print i
# Out:
# id
# name
# sal

# %%
# to get from index use .loc
df.loc['2016-01-31']
# Out:
# id           1
# name      Anil
# sal     300000
# Name: 2016-01-31 00:00:00, dtype: object

# %%
df.loc['2016-01-31':'2016-04-30']
# Out:
#             id    name     sal
# 2016-01-31   1    Anil  300000
# 2016-02-29   5  Rajesh  400000
# 2016-03-31   4   Pavan  500000
# 2016-04-30   6   Ashok  600000

# %%
df.loc['2016-01-31':'2016-04-30','id']
# Out:
# 2016-01-31    1
# 2016-02-29    5
# 2016-03-31    4
# 2016-04-30    6
# Freq: M, Name: id, dtype: int64

# %%
df.loc['2016-01-31':'2016-04-30','id':]
# Out:
#             id    name     sal
# 2016-01-31   1    Anil  300000
# 2016-02-29   5  Rajesh  400000
# 2016-03-31   4   Pavan  500000
# 2016-04-30   6   Ashok  600000

# %%
# column slicing follows the list order in df.columns but not the alphabetical order of columns
df.loc['2016-01-31':'2016-04-30',:'name']
# Out:
#             id    name
# 2016-01-31   1    Anil
# 2016-02-29   5  Rajesh
# 2016-03-31   4   Pavan
# 2016-04-30   6   Ashok

# %%
df.loc['2016-01-31':'2016-04-30','name':'sal']
# Out:
#               name     sal
# 2016-01-31    Anil  300000
# 2016-02-29  Rajesh  400000
# 2016-03-31   Pavan  500000
# 2016-04-30   Ashok  600000

# %%
#to get from position
df.iloc[0]
# Out:
# id           1
# name      Anil
# sal     300000
# Name: 2016-01-31 00:00:00, dtype: object

# %%
df.iloc[-1]
# Out:
# id            2
# name    Jadeesh
# sal      500000
# Name: 2016-06-30 00:00:00, dtype: object

# %%
# .ix can get the row using position or an index
df.ix[0]
# Out:
# id           1
# name      Anil
# sal     300000
# Name: 2016-01-31 00:00:00, dtype: object

# %%
df.ix['2016-01-31']
# Out:
# id           1
# name      Anil
# sal     300000
# Name: 2016-01-31 00:00:00, dtype: object

# %%
df.ix[-1]
# Out:
# id            2
# name    Jadeesh
# sal      500000
# Name: 2016-06-30 00:00:00, dtype: object

# %%
df
# Out:
#             id     name     sal
# 2016-01-31   1     Anil  300000
# 2016-02-29   5   Rajesh  400000
# 2016-03-31   4    Pavan  500000
# 2016-04-30   6    Ashok  600000
# 2016-05-31   3   Naveen  200000
# 2016-06-30   2  Jadeesh  500000

# %%
# head and tail
df.head() # gives first five rows
# Out:
#             id    name     sal
# 2016-01-31   1    Anil  300000
# 2016-02-29   5  Rajesh  400000
# 2016-03-31   4   Pavan  500000
# 2016-04-30   6   Ashok  600000
# 2016-05-31   3  Naveen  200000

# %%
df.head(10) # first ten rows
# Out:
#             id     name     sal
# 2016-01-31   1     Anil  300000
# 2016-02-29   5   Rajesh  400000
# 2016-03-31   4    Pavan  500000
# 2016-04-30   6    Ashok  600000
# 2016-05-31   3   Naveen  200000
# 2016-06-30   2  Jadeesh  500000

# %%
df.tail() # gives a last five rows
# Out:
#             id     name     sal
# 2016-02-29   5   Rajesh  400000
# 2016-03-31   4    Pavan  500000
# 2016-04-30   6    Ashok  600000
# 2016-05-31   3   Naveen  200000
# 2016-06-30   2  Jadeesh  500000

# %%
df.tail(10) # gives a last ten rows
# Out:
#             id     name     sal
# 2016-01-31   1     Anil  300000
# 2016-02-29   5   Rajesh  400000
# 2016-03-31   4    Pavan  500000
# 2016-04-30   6    Ashok  600000
# 2016-05-31   3   Naveen  200000
# 2016-06-30   2  Jadeesh  500000

# %%
# core slicing
df[0:3]
# Out:
#             id    name     sal
# 2016-01-31   1    Anil  300000
# 2016-02-29   5  Rajesh  400000
# 2016-03-31   4   Pavan  500000

# %%
df[:3]
# Out:
#             id    name     sal
# 2016-01-31   1    Anil  300000
# 2016-02-29   5  Rajesh  400000
# 2016-03-31   4   Pavan  500000

# %%
df[-4:-1]
# Out:
#             id    name     sal
# 2016-03-31   4   Pavan  500000
# 2016-04-30   6   Ashok  600000
# 2016-05-31   3  Naveen  200000

# %%
df['name']
# Out:
# 2016-01-31       Anil
# 2016-02-29     Rajesh
# 2016-03-31      Pavan
# 2016-04-30      Ashok
# 2016-05-31     Naveen
# 2016-06-30    Jadeesh
# Freq: M, Name: name, dtype: object

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#      id      name       doj       dob    salary address  rank
# 0   123     Sunil  01/01/15  01/03/89  560000.0     ad1   2.0
# 1   124    Rajesh  01/03/14  01/04/88  600000.0     ad1   3.0
# 2   125     Pavan  01/04/16  01/04/96  400000.0     ad2  20.0
# 3   126      Anil  01/01/15  02/03/89  560000.0     ad3   1.0
# 4   127  Sudhakar  01/03/14  02/04/88  600000.0     ad4   4.0
# 5   128      Anil  01/04/16  02/04/96  400000.0     ad1   5.0
# 6   129     Ashok  01/01/15  03/03/89  560000.0     ad1   7.0
# 7   130    Naveen  01/03/14  03/04/88  600000.0     ad2   8.0
# 8   131    Sreenu  01/04/16  03/04/96  400000.0     ad3   9.0
# 9   132     Sunil  01/01/15  01/03/89  560000.0     ad1  21.0
# 10  133    Rajesh  01/03/14  01/04/88  600000.0     ad1  22.0
# 11  134     Pavan  01/04/16  01/04/96       NaN     ad2   NaN
# 12  135      Anil  01/01/15  02/03/89  560000.0     NaN  34.0
# 13  136  Sudhakar  01/03/14  02/04/88  600000.0     ad4  56.0
# 14  137      Anil  01/04/16  02/04/96       NaN     NaN  78.0
# 15  138     Ashok  01/01/15  03/03/89  560000.0     ad1   NaN
# 16  139    Naveen  01/03/14  03/04/88  600000.0     ad2  69.0
# 17  140    Sreenu  01/04/16  03/04/96  400000.0     ad3   NaN

# %%
data = pd.read_csv("data.csv")
data
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1          id       name        doj        dob     salary    address
# 2         123      Sunil   01/01/15   01/03/89     560000        ad1
# 3         124     Rajesh   01/03/14   01/04/88     600000        ad1
# 4         125      Pavan   01/04/16   01/04/96     400000        ad2
# 5         126       Anil   01/01/15   02/03/89     560000        ad3
# 6         127   Sudhakar   01/03/14   02/04/88     600000        ad4
# 7         128       Anil   01/04/16   02/04/96     400000        ad1
# 8         129      Ashok   01/01/15   03/03/89     560000        ad1
# 9         130     Naveen   01/03/14   03/04/88     600000        ad2
# 10        131     Sreenu   01/04/16   03/04/96     400000        ad3
# 11        132      Sunil   01/01/15   01/03/89     560000        ad1
# 12        133     Rajesh   01/03/14   01/04/88     600000        ad1
# 13        134      Pavan   01/04/16   01/04/96        NaN        ad2
# 14        135       Anil   01/01/15   02/03/89     560000        NaN
# 15        136   Sudhakar   01/03/14   02/04/88     600000        ad4
# 16        137       Anil   01/04/16   02/04/96        NaN        NaN
# 17        138      Ashok   01/01/15   03/03/89     560000        ad1
# 18        139     Naveen   01/03/14   03/04/88     600000        ad2
# 19        140     Sreenu   01/04/16   03/04/96     400000        ad3
#
#    Persons information
# 0            Quarter 3
# 1                 rank
# 2                    2
# 3                    3
# 4                   20
# 5                    1
# 6                    4
# 7                    5
# 8                    7
# 9                    8
# 10                   9
# 11                  21
# 12                  22
# 13                 NaN
# 14                  34
# 15                  56
# 16                  78
# 17                 NaN
# 18                  69
# 19                 NaN

# %%
data = pd.read_csv?

# %%
data = pd.read_csv("data.csv",skiprows=2)
data
# Out:
#      id      name       doj       dob    salary address  rank
# 0   123     Sunil  01/01/15  01/03/89  560000.0     ad1   2.0
# 1   124    Rajesh  01/03/14  01/04/88  600000.0     ad1   3.0
# 2   125     Pavan  01/04/16  01/04/96  400000.0     ad2  20.0
# 3   126      Anil  01/01/15  02/03/89  560000.0     ad3   1.0
# 4   127  Sudhakar  01/03/14  02/04/88  600000.0     ad4   4.0
# 5   128      Anil  01/04/16  02/04/96  400000.0     ad1   5.0
# 6   129     Ashok  01/01/15  03/03/89  560000.0     ad1   7.0
# 7   130    Naveen  01/03/14  03/04/88  600000.0     ad2   8.0
# 8   131    Sreenu  01/04/16  03/04/96  400000.0     ad3   9.0
# 9   132     Sunil  01/01/15  01/03/89  560000.0     ad1  21.0
# 10  133    Rajesh  01/03/14  01/04/88  600000.0     ad1  22.0
# 11  134     Pavan  01/04/16  01/04/96       NaN     ad2   NaN
# 12  135      Anil  01/01/15  02/03/89  560000.0     NaN  34.0
# 13  136  Sudhakar  01/03/14  02/04/88  600000.0     ad4  56.0
# 14  137      Anil  01/04/16  02/04/96       NaN     NaN  78.0
# 15  138     Ashok  01/01/15  03/03/89  560000.0     ad1   NaN
# 16  139    Naveen  01/03/14  03/04/88  600000.0     ad2  69.0
# 17  140    Sreenu  01/04/16  03/04/96  400000.0     ad3   NaN

# %%
data = pd.read_csv("data.csv",skiprows=2)
data
# Out:
#        id      name       doj       dob    salary address                 rank
# 0   123.0     Sunil  01/01/15  01/03/89  560000.0     ad1                    2
# 1   124.0    Rajesh  01/03/14  01/04/88  600000.0     ad1                    3
# 2   125.0     Pavan  01/04/16  01/04/96  400000.0     ad2                   20
# 3   126.0      Anil  01/01/15  02/03/89  560000.0     ad3                    1
# 4   127.0  Sudhakar  01/03/14  02/04/88  600000.0     ad4                    4
# 5   128.0      Anil  01/04/16  02/04/96  400000.0     ad1                    5
# 6   129.0     Ashok  01/01/15  03/03/89  560000.0     ad1                    7
# 7   130.0    Naveen  01/03/14  03/04/88  600000.0     ad2                    8
# 8   131.0    Sreenu  01/04/16  03/04/96  400000.0     ad3                    9
# 9   132.0     Sunil  01/01/15  01/03/89  560000.0     ad1                   21
# 10  133.0    Rajesh  01/03/14  01/04/88  600000.0     ad1                   22
# 11  134.0     Pavan  01/04/16  01/04/96       NaN     ad2                  NaN
# 12  135.0      Anil  01/01/15  02/03/89  560000.0     NaN                   34
# 13  136.0  Sudhakar  01/03/14  02/04/88  600000.0     ad4                   56
# 14  137.0      Anil  01/04/16  02/04/96       NaN     NaN                   78
# 15  138.0     Ashok  01/01/15  03/03/89  560000.0     ad1                  NaN
# 16  139.0    Naveen  01/03/14  03/04/88  600000.0     ad2                   69
# 17  140.0    Sreenu  01/04/16  03/04/96  400000.0     ad3                  NaN
# 18    NaN       NaN       NaN       NaN       NaN     NaN  Persons information
# 19    NaN       NaN       NaN       NaN       NaN     NaN            Quarter 3

# %%
data = pd.read_csv?

# %%
data = pd.read_csv("data.csv",skiprows=2,skipfooter=2,engine="python")
data
# Out:
#      id      name       doj       dob    salary address  rank
# 0   123     Sunil  01/01/15  01/03/89  560000.0     ad1   2.0
# 1   124    Rajesh  01/03/14  01/04/88  600000.0     ad1   3.0
# 2   125     Pavan  01/04/16  01/04/96  400000.0     ad2  20.0
# 3   126      Anil  01/01/15  02/03/89  560000.0     ad3   1.0
# 4   127  Sudhakar  01/03/14  02/04/88  600000.0     ad4   4.0
# 5   128      Anil  01/04/16  02/04/96  400000.0     ad1   5.0
# 6   129     Ashok  01/01/15  03/03/89  560000.0     ad1   7.0
# 7   130    Naveen  01/03/14  03/04/88  600000.0     ad2   8.0
# 8   131    Sreenu  01/04/16  03/04/96  400000.0     ad3   9.0
# 9   132     Sunil  01/01/15  01/03/89  560000.0     ad1  21.0
# 10  133    Rajesh  01/03/14  01/04/88  600000.0     ad1  22.0
# 11  134     Pavan  01/04/16  01/04/96       NaN     ad2   NaN
# 12  135      Anil  01/01/15  02/03/89  560000.0     NaN  34.0
# 13  136  Sudhakar  01/03/14  02/04/88  600000.0     ad4  56.0
# 14  137      Anil  01/04/16  02/04/96       NaN     NaN  78.0
# 15  138     Ashok  01/01/15  03/03/89  560000.0     ad1   NaN
# 16  139    Naveen  01/03/14  03/04/88  600000.0     ad2  69.0
# 17  140    Sreenu  01/04/16  03/04/96  400000.0     ad3   NaN

# %%
data.plot(x='id',y="salary",kind="bar")
plt.show()

# %%
data.plot(x='id',y="salary",kind="bar",legend=False)
plt.show()

# %%
type(data.ix[0]['doj'])
# Out:
# str

# %%
data.ix[0:4][['doj','dob']]
# Out:
#         doj       dob
# 0  01/01/15  01/03/89
# 1  01/03/14  01/04/88
# 2  01/04/16  01/04/96
# 3  01/01/15  02/03/89
# 4  01/03/14  02/04/88

# %%
data = pd.read_csv("data.csv",skiprows=2,skipfooter=2,engine="python",parse_dates=['doj','dob'])
data
# Out:
#      id      name        doj        dob    salary address  rank
# 0   123     Sunil 2015-01-01 1989-01-03  560000.0     ad1   2.0
# 1   124    Rajesh 2014-01-03 1988-01-04  600000.0     ad1   3.0
# 2   125     Pavan 2016-01-04 1996-01-04  400000.0     ad2  20.0
# 3   126      Anil 2015-01-01 1989-02-03  560000.0     ad3   1.0
# 4   127  Sudhakar 2014-01-03 1988-02-04  600000.0     ad4   4.0
# 5   128      Anil 2016-01-04 1996-02-04  400000.0     ad1   5.0
# 6   129     Ashok 2015-01-01 1989-03-03  560000.0     ad1   7.0
# 7   130    Naveen 2014-01-03 1988-03-04  600000.0     ad2   8.0
# 8   131    Sreenu 2016-01-04 1996-03-04  400000.0     ad3   9.0
# 9   132     Sunil 2015-01-01 1989-01-03  560000.0     ad1  21.0
# 10  133    Rajesh 2014-01-03 1988-01-04  600000.0     ad1  22.0
# 11  134     Pavan 2016-01-04 1996-01-04       NaN     ad2   NaN
# 12  135      Anil 2015-01-01 1989-02-03  560000.0     NaN  34.0
# 13  136  Sudhakar 2014-01-03 1988-02-04  600000.0     ad4  56.0
# 14  137      Anil 2016-01-04 1996-02-04       NaN     NaN  78.0
# 15  138     Ashok 2015-01-01 1989-03-03  560000.0     ad1   NaN
# 16  139    Naveen 2014-01-03 1988-03-04  600000.0     ad2  69.0
# 17  140    Sreenu 2016-01-04 1996-03-04  400000.0     ad3   NaN

# %%
data.iloc[0]['doj']
# Out:
# Timestamp('2015-01-01 00:00:00')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=18, step=1)

# %%
data = pd.read_csv("data.csv",skiprows=2,skipfooter=2,engine="python",parse_dates=['doj','dob'],index_col='dob')
data
# Out:
#              id      name        doj    salary address  rank
# dob
# 1989-01-03  123     Sunil 2015-01-01  560000.0     ad1   2.0
# 1988-01-04  124    Rajesh 2014-01-03  600000.0     ad1   3.0
# 1996-01-04  125     Pavan 2016-01-04  400000.0     ad2  20.0
# 1989-02-03  126      Anil 2015-01-01  560000.0     ad3   1.0
# 1988-02-04  127  Sudhakar 2014-01-03  600000.0     ad4   4.0
# 1996-02-04  128      Anil 2016-01-04  400000.0     ad1   5.0
# 1989-03-03  129     Ashok 2015-01-01  560000.0     ad1   7.0
# 1988-03-04  130    Naveen 2014-01-03  600000.0     ad2   8.0
# 1996-03-04  131    Sreenu 2016-01-04  400000.0     ad3   9.0
# 1989-01-03  132     Sunil 2015-01-01  560000.0     ad1  21.0
# 1988-01-04  133    Rajesh 2014-01-03  600000.0     ad1  22.0
# 1996-01-04  134     Pavan 2016-01-04       NaN     ad2   NaN
# 1989-02-03  135      Anil 2015-01-01  560000.0     NaN  34.0
# 1988-02-04  136  Sudhakar 2014-01-03  600000.0     ad4  56.0
# 1996-02-04  137      Anil 2016-01-04       NaN     NaN  78.0
# 1989-03-03  138     Ashok 2015-01-01  560000.0     ad1   NaN
# 1988-03-04  139    Naveen 2014-01-03  600000.0     ad2  69.0
# 1996-03-04  140    Sreenu 2016-01-04  400000.0     ad3   NaN

# %%
data.index
# Out:
# DatetimeIndex(['1989-01-03', '1988-01-04', '1996-01-04', '1989-02-03',
#                '1988-02-04', '1996-02-04', '1989-03-03', '1988-03-04',
#                '1996-03-04', '1989-01-03', '1988-01-04', '1996-01-04',
#                '1989-02-03', '1988-02-04', '1996-02-04', '1989-03-03',
#                '1988-03-04', '1996-03-04'],
#               dtype='datetime64[ns]', name=u'dob', freq=None)

# %%
data.columns
# Out:
# Index([u'id', u'name', u'doj', u'salary', u'address', u'rank'], dtype='object')

# %%
data.sort_index()
# Out:
#              id      name        doj    salary address  rank
# dob
# 1988-01-04  124    Rajesh 2014-01-03  600000.0     ad1   3.0
# 1988-01-04  133    Rajesh 2014-01-03  600000.0     ad1  22.0
# 1988-02-04  127  Sudhakar 2014-01-03  600000.0     ad4   4.0
# 1988-02-04  136  Sudhakar 2014-01-03  600000.0     ad4  56.0
# 1988-03-04  130    Naveen 2014-01-03  600000.0     ad2   8.0
# 1988-03-04  139    Naveen 2014-01-03  600000.0     ad2  69.0
# 1989-01-03  123     Sunil 2015-01-01  560000.0     ad1   2.0
# 1989-01-03  132     Sunil 2015-01-01  560000.0     ad1  21.0
# 1989-02-03  126      Anil 2015-01-01  560000.0     ad3   1.0
# 1989-02-03  135      Anil 2015-01-01  560000.0     NaN  34.0
# 1989-03-03  129     Ashok 2015-01-01  560000.0     ad1   7.0
# 1989-03-03  138     Ashok 2015-01-01  560000.0     ad1   NaN
# 1996-01-04  125     Pavan 2016-01-04  400000.0     ad2  20.0
# 1996-01-04  134     Pavan 2016-01-04       NaN     ad2   NaN
# 1996-02-04  128      Anil 2016-01-04  400000.0     ad1   5.0
# 1996-02-04  137      Anil 2016-01-04       NaN     NaN  78.0
# 1996-03-04  131    Sreenu 2016-01-04  400000.0     ad3   9.0
# 1996-03-04  140    Sreenu 2016-01-04  400000.0     ad3   NaN

# %%
data.sort_index(inplace=True)

# %%
data
# Out:
#              id      name        doj    salary address  rank
# dob
# 1988-01-04  124    Rajesh 2014-01-03  600000.0     ad1   3.0
# 1988-01-04  133    Rajesh 2014-01-03  600000.0     ad1  22.0
# 1988-02-04  127  Sudhakar 2014-01-03  600000.0     ad4   4.0
# 1988-02-04  136  Sudhakar 2014-01-03  600000.0     ad4  56.0
# 1988-03-04  130    Naveen 2014-01-03  600000.0     ad2   8.0
# 1988-03-04  139    Naveen 2014-01-03  600000.0     ad2  69.0
# 1989-01-03  123     Sunil 2015-01-01  560000.0     ad1   2.0
# 1989-01-03  132     Sunil 2015-01-01  560000.0     ad1  21.0
# 1989-02-03  126      Anil 2015-01-01  560000.0     ad3   1.0
# 1989-02-03  135      Anil 2015-01-01  560000.0     NaN  34.0
# 1989-03-03  129     Ashok 2015-01-01  560000.0     ad1   7.0
# 1989-03-03  138     Ashok 2015-01-01  560000.0     ad1   NaN
# 1996-01-04  125     Pavan 2016-01-04  400000.0     ad2  20.0
# 1996-01-04  134     Pavan 2016-01-04       NaN     ad2   NaN
# 1996-02-04  128      Anil 2016-01-04  400000.0     ad1   5.0
# 1996-02-04  137      Anil 2016-01-04       NaN     NaN  78.0
# 1996-03-04  131    Sreenu 2016-01-04  400000.0     ad3   9.0
# 1996-03-04  140    Sreenu 2016-01-04  400000.0     ad3   NaN

# %%
data.sort_values(by="name",inplace=True)

# %%
data
# Out:
#              id      name        doj    salary address  rank
# dob
# 1989-02-03  126      Anil 2015-01-01  560000.0     ad3   1.0
# 1996-02-04  137      Anil 2016-01-04       NaN     NaN  78.0
# 1996-02-04  128      Anil 2016-01-04  400000.0     ad1   5.0
# 1989-02-03  135      Anil 2015-01-01  560000.0     NaN  34.0
# 1989-03-03  138     Ashok 2015-01-01  560000.0     ad1   NaN
# 1989-03-03  129     Ashok 2015-01-01  560000.0     ad1   7.0
# 1988-03-04  130    Naveen 2014-01-03  600000.0     ad2   8.0
# 1988-03-04  139    Naveen 2014-01-03  600000.0     ad2  69.0
# 1996-01-04  134     Pavan 2016-01-04       NaN     ad2   NaN
# 1996-01-04  125     Pavan 2016-01-04  400000.0     ad2  20.0
# 1988-01-04  124    Rajesh 2014-01-03  600000.0     ad1   3.0
# 1988-01-04  133    Rajesh 2014-01-03  600000.0     ad1  22.0
# 1996-03-04  131    Sreenu 2016-01-04  400000.0     ad3   9.0
# 1996-03-04  140    Sreenu 2016-01-04  400000.0     ad3   NaN
# 1988-02-04  136  Sudhakar 2014-01-03  600000.0     ad4  56.0
# 1988-02-04  127  Sudhakar 2014-01-03  600000.0     ad4   4.0
# 1989-01-03  132     Sunil 2015-01-01  560000.0     ad1  21.0
# 1989-01-03  123     Sunil 2015-01-01  560000.0     ad1   2.0

# %%
data[data['name']=="Anil"]
# Out:
#              id  name        doj    salary address  rank
# dob
# 1989-02-03  126  Anil 2015-01-01  560000.0     ad3   1.0
# 1996-02-04  137  Anil 2016-01-04       NaN     NaN  78.0
# 1996-02-04  128  Anil 2016-01-04  400000.0     ad1   5.0
# 1989-02-03  135  Anil 2015-01-01  560000.0     NaN  34.0
